# %%
import pandas as pd#impoting the required packages
import numpy as np
gold= pd.read_csv("../data/gold.csv",index_col=0)#providing the directory to the data folder to obtain the gold.csv file

# %%
gold_sample=gold.sample(n=1000)#randomly taking a sample of 1000 rows from the gold dataset
gold_sample.to_csv("../data/gold_sample.csv")#storing the gold sample in the data folder as mentioned
gold_sample.head()#showing the sample folder.
# Out:
#         TOPIC0    TOPIC1    TOPIC2    TOPIC3    TOPIC4    TOPIC5    TOPIC6  \
# id
# 7153  0.189778  0.028247  0.082636  0.242747  0.037713  0.145649  0.093700
# 7951  0.609251  0.772423 -0.227274  0.066121  0.294486  0.554525  0.286519
# 4026  0.909468  0.906008  0.691776 -0.394227 -0.342606 -0.101572 -0.809699
# 7261  0.254962  0.064148  0.186428  0.606833  0.473354 -0.550509 -0.250238
# 4875  0.130645  0.002654  0.088650  0.199359  0.027583  0.225762 -0.005165
#
#         TOPIC7    TOPIC8    TOPIC9  ...    TOPIC1191  TOPIC1192  TOPIC1193  \
# id                                  ...
# 7153 -0.138572  0.131927 -0.601126  ...     0.034746   0.008808   0.086159
# 7951  0.440216 -0.375146  0.288990  ...     0.020882  -0.005793   0.129757
# 4026  0.409908 -0.112820  0.192804  ...    -0.014560   0.048796  -0.008395
# 7261  0.130667  0.076447  0.049817  ...     0.004710   0.006922   0.044617
# 4875 -0.105642  0.820503  0.369489  ...    -0.012107  -0.044665  -0.072195
#
# ...
